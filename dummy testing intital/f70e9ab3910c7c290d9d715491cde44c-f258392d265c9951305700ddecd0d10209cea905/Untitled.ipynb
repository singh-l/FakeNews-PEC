# %%
import tweepy
import csv
import pandas as pd
####input your credentials here
consumer_key = 'xATXprD7x5LxkUoYCKnYGBh65'
consumer_secret = 'N0OMvq4sVKCWMU3pEL1YqrmpUtYlmZbZfDQrVgzlYVIbyoAJBo'
access_token = '1175415692914331649-evjPc46YKy4z0YFuy0rIbgH3m5ljiW'
access_token_secret = 'A99F0SysSPBWs6hUdD8Z7WLqfdlXXbWHO5QJxd5EyZITw'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
#####United Airlines
# Open/Create a file to append data
csvFile = open('Chennaifloodsdata.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)

csvWriter.writerow(["created at", "text" ,"user_screenname", "user_location", "retweets", "favorites"])

for tweet in tweepy.Cursor(api.search,q="#chennai",
                           lang="en",
                           since="2018-01-01").items():
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.user.screen_name, tweet.user.location, tweet.retweet_count, tweet.favorite_count])
# Out:
# 2019-09-22 19:05:41 RT @TrendsChennai: #askprashanth is now trending in #Chennai
#
# https://t.co/bRbxh4HIWj https://t.co/5qbe6k6Qvi
# 2019-09-22 19:04:44 RT @BloodDonorsIn: #Chennai
# Need #Blood Type :  B-negative
# At : MMM Hospital, Mogappair
# Number of Units : 6
# Primary Number : 9094288509
# Sec…
# 2019-09-22 19:03:45 RT @alishaabdullah: Since a lot of request poured in for this priceless pic.. here it is... Soon to get a new pic from the Master himself…
# 2019-09-22 19:00:33 #askprashanth is now trending in #Chennai
#
# https://t.co/bRbxh4HIWj https://t.co/5qbe6k6Qvi
# 2019-09-22 18:59:36 RT @rkrishnamani: Tried animating the illo( created for culture trip), to give it more dynamic, parallax effect pan and zoom.
# #illustratio…
# 2019-09-22 18:58:43 RT @BloodDonorsIn: #Chennai
# Need #Blood Type :  B-negative
# At : MMM Hospital, Mogappair
# Number of Units : 6
# Primary Number : 9094288509
# Sec…
# ...
